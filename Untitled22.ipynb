# %% [markdown]
# <a href="https://colab.research.google.com/github/shahbaz123-gif/INTRODUCTION-to-pandas/blob/main/Untitled22.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import numpy as np
import matplot.pyplot as plt
import seaborn as sns
import warnings
warnings.filterwarnings('ignore')

# %%
df = pd.read_csv('heart.csv')

# %%
df.head()

# %%
df.shape

# %%
df.columns

index(['age', 'sex', 'cp', 'trestbps', 'chol', 'fbs', 'restecg', 'thalach', 'exang', 'oldpeak', 'slope', 'ca', 'thal', 'target'], dtype='object')

# %%
df.describe()

# %%
df.insull

# %%
print(df.info())

# %%
plt.figure(figsize=(20,10))
sns.heatmap(df.corr(), annot=True, cmap='terrain')

# %%
sns.pairplot(data=df)

# %%
df.hist(figsize=(12,12), layout=(5,3))

# %%
df.plot(kind = 'box', subplots=True, layout=(5, 3), figsize=(12,12))
plt.show()

# %%
sns.barplot(data=df, x='sex', y='chol', hue='target', palette='spring')

# %%
df['sex'].value_counts()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# /tmp/ipykernel_722/525347501.py in <cell line: 0>()
# ----> 1 df['sex'].value_counts()
#
# NameError: name 'df' is not defined

# %%
df['target'].value_counts()

# %%
sns.countplot(x='sex', data=df, palette='husl', hue)
